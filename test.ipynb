# %%
from Brain_Energy import BrainEnergy

# %%
df = BrainEnergy(r'rois_cc200\NYU_0050954_rois_cc200.1D', windows_size= 175)

# %%
read =df.data_reader()

# %%
a, b = read.shape

# %%
corr = df.correlation()

# %%
corr
# Out:
# array([[ 1.        , -0.26232892, -0.2118991 , ...,  0.30230341,
#         -0.28690757,  0.33227307],
#        [-0.26232892,  1.        ,  0.48815378, ..., -0.16265009,
#          0.17891864, -0.35886937],
#        [-0.2118991 ,  0.48815378,  1.        , ..., -0.01608858,
#          0.23818071, -0.27236099],
#        ...,
#        [ 0.30230341, -0.16265009, -0.01608858, ...,  1.        ,
#          0.07774345, -0.05683577],
#        [-0.28690757,  0.17891864,  0.23818071, ...,  0.07774345,
#          1.        , -0.12974881],
#        [ 0.33227307, -0.35886937, -0.27236099, ..., -0.05683577,
#         -0.12974881,  1.        ]])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 max(corr.all)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
read[0:1]

# %%
read[:1].values

# %%
len(read)

# %%
ene = df.energy()
# Out:
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900
# 19900

# %%
ene
# Out:
# {'1th time-point': -2.3154839947149,
#  '2th time-point': -5.28311941668386,
#  '3th time-point': -2.2464660582516394,
#  '4th time-point': -4.221758873913091,
#  '5th time-point': -14.962581813123435,
#  '6th time-point': -15.385544649920176,
#  '7th time-point': -13.450278654021583,
#  '8th time-point': -22.13307805038521,
#  '9th time-point': -19.98294561327913,
#  '10th time-point': -7.1312998885974395,
#  '11th time-point': -10.83351084756293,
#  '12th time-point': -20.756520725506647,
#  '13th time-point': -13.9017552602544,
#  '14th time-point': -4.079473452153756,
#  '15th time-point': -4.401980809805133,
#  '16th time-point': -6.871826865943399,
#  '17th time-point': -6.245562636352467,
#  '18th time-point': -3.459215153961929,
#  '19th time-point': -8.588282908181824,
#  '20th time-point': -20.694765109365523,
#  '21th time-point': -19.864085367911446,
#  '22th time-point': -9.689490597021601,
#  '23th time-point': -7.166268098048397,
#  '24th time-point': -9.691539314533614,
#  '25th time-point': -11.428500112655707,
#  '26th time-point': -16.226583995418924,
#  '27th time-point': -20.1408957876584,
#  '28th time-point': -8.816383520944608,
#  '29th time-point': -3.7334250296849354,
#  '30th time-point': -24.459574167035754,
#  '31th time-point': -28.747327387636826,
#  '32th time-point': -17.4528176755339,
#  '33th time-point': -28.040743376340007,
#  '34th time-point': -29.510085495816096,
#  '35th time-point': -11.699797482111467,
#  '36th time-point': -4.578498213982549,
#  '37th time-point': -6.123800285750074,
#  '38th time-point': -13.522067331025358,
#  '39th time-point': -16.177597871488768,
#  '40th time-point': -10.831034937054179,
#  '41th time-point': -18.324614605185275,
#  '42th time-point': -23.644773369715978,
#  '43th time-point': -15.517236011303416,
#  '44th time-point': -15.330673976013234,
#  '45th time-point': -22.779927411591935,
#  '46th time-point': -28.096257346901083,
#  '47th time-point': -25.25431784768354,
#  '48th time-point': -12.706698587682013,
#  '49th time-point': -4.320163895200016,
#  '50th time-point': -3.404033051996383,
#  '51th time-point': -6.193636772382894,
#  '52th time-point': -16.066363902620168,
#  '53th time-point': -22.842199506610815,
#  '54th time-point': -18.033357121189784,
#  '55th time-point': -14.666204158613041,
#  '56th time-point': -17.117369723092178,
#  '57th time-point': -21.837932799429122,
#  '58th time-point': -36.311398448056934,
#  '59th time-point': -40.83973284034672,
#  '60th time-point': -16.468337455176485,
#  '61th time-point': -13.311324304731858,
#  '62th time-point': -52.078686736270235,
#  '63th time-point': -66.45613859303646,
#  '64th time-point': -42.957637759815626,
#  '65th time-point': -27.2242555998939,
#  '66th time-point': -16.00425516381599,
#  '67th time-point': -7.587247066220508,
#  '68th time-point': -26.28199514531008,
#  '69th time-point': -45.59216679535551,
#  '70th time-point': -32.54343909983057,
#  '71th time-point': -12.58094892990322,
#  '72th time-point': -12.160392384636017,
#  '73th time-point': -18.457953746495175,
#  '74th time-point': -14.317746056621923,
#  '75th time-point': -7.486287153451186,
#  '76th time-point': -8.013309409095138,
#  '77th time-point': -7.395189073734312,
#  '78th time-point': -8.017304530909414,
#  '79th time-point': -15.277765145836698,
#  '80th time-point': -13.370986379275967,
#  '81th time-point': -6.44710749038455,
#  '82th time-point': -11.291096605080739,
#  '83th time-point': -14.258444510473051,
#  '84th time-point': -8.887754624756667,
#  '85th time-point': -9.081011574773516,
#  '86th time-point': -10.976852641505365,
#  '87th time-point': -11.126434506254668,
#  '88th time-point': -19.049845439906942,
#  '89th time-point': -27.17173015901627,
#  '90th time-point': -26.50980084092299,
#  '91th time-point': -24.25258858914208,
#  '92th time-point': -18.4846606545449,
#  '93th time-point': -8.568742419277688,
#  '94th time-point': -5.240541572233604,
#  '95th time-point': -5.568004641717025,
#  '96th time-point': -6.34338695630769,
#  '97th time-point': -11.623802913623923,
#  '98th time-point': -12.571594829723205,
#  '99th time-point': -7.310982750691451,
#  '100th time-point': -8.353564403949814,
#  '101th time-point': -15.481544994777767,
#  '102th time-point': -20.99011625892203,
#  '103th time-point': -25.151011842397896,
#  '104th time-point': -26.60634532588457,
#  '105th time-point': -25.2476631689869,
#  '106th time-point': -30.62462138872905,
#  '107th time-point': -34.885333505370454,
#  '108th time-point': -21.33148251172491,
#  '109th time-point': -8.711009117105503,
#  '110th time-point': -10.827202902430397,
#  '111th time-point': -10.640182094574243,
#  '112th time-point': -13.37697620473753,
#  '113th time-point': -25.909810021046145,
#  '114th time-point': -28.46715575426341,
#  '115th time-point': -20.027563766078934,
#  '116th time-point': -16.191768042442014,
#  '117th time-point': -16.33041928528391,
#  '118th time-point': -12.462549088096132,
#  '119th time-point': -8.482760704510493,
#  '120th time-point': -10.448067871184753,
#  '121th time-point': -11.682661948969965,
#  '122th time-point': -13.426735145936732,
#  '123th time-point': -17.601040692111997,
#  '124th time-point': -12.42583952880877,
#  '125th time-point': -7.832733614628552,
#  '126th time-point': -13.274310361662758,
#  '127th time-point': -14.676867464390904,
#  '128th time-point': -17.263639831351316,
#  '129th time-point': -24.151569812601007,
#  '130th time-point': -25.300826464099565,
#  '131th time-point': -31.591222521696167,
#  '132th time-point': -37.65559999558779,
#  '133th time-point': -25.481968249125213,
#  '134th time-point': -11.635812906858712,
#  '135th time-point': -9.429393701731428,
#  '136th time-point': -13.978272785365789,
#  '137th time-point': -32.253626932342506,
#  '138th time-point': -58.89399097044867,
#  '139th time-point': -69.17423211806725,
#  '140th time-point': -57.76584109089606,
#  '141th time-point': -44.43084572901238,
#  '142th time-point': -43.84790048319409,
#  '143th time-point': -43.014929128581336,
#  '144th time-point': -26.329536877944985,
#  '145th time-point': -9.955053698992744,
#  '146th time-point': -15.859683003692941,
#  '147th time-point': -44.04551154270009,
#  '148th time-point': -84.41677711521054,
#  '149th time-point': -127.80905208839789,
#  '150th time-point': -156.7736570666606,
#  '151th time-point': -131.98338115344407,
#  '152th time-point': -56.350105957570776,
#  '153th time-point': -14.999633260179126,
#  '154th time-point': -38.43853650732376,
#  '155th time-point': -54.761892548249136,
#  '156th time-point': -33.83977785522223,
#  '157th time-point': -12.930878790841488,
#  '158th time-point': -11.462091100901498,
#  '159th time-point': -18.397107308371876,
#  '160th time-point': -18.656386201064002,
#  '161th time-point': -9.244237752562874,
#  '162th time-point': -4.629186098195979,
#  '163th time-point': -20.38951049855263,
#  '164th time-point': -39.216385994156745,
#  '165th time-point': -35.21086754137598,
#  '166th time-point': -23.517633213420865,
#  '167th time-point': -15.563915171364378,
#  '168th time-point': -6.372347446973539,
#  '169th time-point': -13.980497138471426,
#  '170th time-point': -28.622454965438195,
#  '171th time-point': -20.17583067350174,
#  '172th time-point': -6.113428228449885,
#  '173th time-point': -5.568169735722626,
#  '174th time-point': -7.060932439679276,
#  '175th time-point': -5.622769722864696}

# %%
min(ene.values())
# Out:
# -156.7736570666606

# %%
50*199

# %%
15400*2

# %%
import pandas as pd
import csv
def save_file2(halftime):
    csv_file = 'output2.csv'

    # Extract keys and values as rows
    rows = [{'Key': key, 'Value': value} for key, value in halftime.items()]

    # Define column names
    fieldnames = ['Key', 'Value']

    # Write the data to the CSV file
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        
        # Write the header row
        writer.writeheader()
        
        # Write the data rows
        writer.writerows(rows)

# %%
save_file2(ene)

# %%
float(2.0154)
